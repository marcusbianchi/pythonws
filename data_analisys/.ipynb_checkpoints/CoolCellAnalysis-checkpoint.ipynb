# %%
# %matplotlib notebook
import pandas as pd

# %%
df = pd.read_csv('Pasta1.csv')

# %%
df
# Out:
#        Index  Position_1  Position_2  Position_3  Position_4  Position_5  \
# 0          9           1           1           4           6           4
# 1         10           1           1           4           6           4
# 2         11           1           1           4           6           4
# 3         12           1           1           4           6           4
# 4         13           1           1           4           6           4
# 5         14           1           1           4           6           4
# 6         15           1           1           4           6           4
# 7         16           1           1           4           6           4
# 8         17           1           1           4           6           4
# 9         18           1           1           4           6           4
# 10        19           0           0           0           0           0
# 11        20           1           1           4           6           4
# ...

# %%
import matplotlib.pyplot as plt

# %%
df.plot(y='Deltatemp1',x='DataTime)
# Out:
# Index                  int64
# Position_1             int64
# Position_2             int64
# Position_3             int64
# Position_4             int64
# Position_5             int64
# Position_6             int64
# Position_7           float64
# Position_8             int64
# Position_9             int64
# Position_10            int64
# Position_11          float64
# Position_12          float64
# Position_13          float64
# Position_14            int64
# Position_15            int64
# Position_16            int64
# Position_17            int64
# Position_18            int64
# Position_19            int64
# Position_20            int64
# Position_21            int64
# Position_22            int64
# Position_23            int64
# Position_24            int64
# Position_25            int64
# Position_26            int64
# Position_27            int64
# Position_28            int64
# Position_29            int64
#                       ...
# Position_32            int64
# ...

# %%
plt.show()
